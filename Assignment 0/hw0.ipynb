# %%
#Task 3
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,2,7,14])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
#Task 4
import numpy as np

t = np.arange(-50, 50, 0.1)
f = np.sin(t)
plt.plot(t, f)
plt.show()
